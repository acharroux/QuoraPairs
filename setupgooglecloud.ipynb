# %%
import pandas
res=pandas.read_pickle('./BruteForce/challenge_questions_question_1_50.pkl')

# %%
res
# Out:
#              1_50_LOC_state_confidence 1_50_LOC_mount_confidence  \
# origin_index
# 0                        2.7048059E-21              1.681158E-20
# 1                        1.7687421E-15             5.8709565E-15
# 2                        1.4155024E-19               5.57723E-20
# 3                        2.6221532E-32             1.1003986E-30
# 4                         7.795989E-22              2.786882E-21
# ...                                ...                       ...
# 3563470                  8.6665696E-32             1.3750697E-31
# 3563471                  3.3028675E-23             1.0153891E-22
# 3563472                  1.1046854E-25             4.3974903E-25
# 3563473                  1.9768351E-18              7.437339E-18
# 3563474                  4.7101846E-19               4.84421E-19
#
#              1_50_ENTY_veh_confidence 1_50_HUM_title_confidence  \
# origin_index
# 0                       1.5587366E-20             8.4708805E-23
# ...

# %%
res.to_csv('./BruteForce/challenge_questions_question_1_50.csv',index=False)

# %%
res = pandas.read_pickle('./PandasStore/clean_training.pkl')
res
# Out:
#             id    qid1    qid2  \
# 0            0       1       2
# 1            1       3       4
# 2            2       5       6
# 3            3       7       8
# 4            4       9      10
# ...        ...     ...     ...
# 404285  404285  433578  379845
# 404286  404286   18840  155606
# 404287  404287  537928  537929
# 404288  404288  537930  537931
# 404289  404289  537932  537933
#
#                                                 question1  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404285  How many keywords are there in the Racket prog...
# 404286          Do you believe there is life after death?
# ...

# %%
res = pandas.read_pickle('./PandasStore/clean_challenge.pkl')
res
# Out:
#          test_id                                          question1  \
# 0              0  How does the Surface Pro himself 4 compare wit...
# 1              1  Should I have a hair transplant at age 24? How...
# 2              2  What but is the best way to send money from Ch...
# 3              3                        Which food not emulsifiers?
# 4              4                   How "aberystwyth" start reading?
# ...          ...                                                ...
# 2345791  2345791  How do Peaks (TV series): Why did Leland kill ...
# 2345792  2345792  What does be "in transit" mean on FedEx tracking?
# 2345793  2345793  What are some famous Romanian drinks (alcoholi...
# 2345794  2345794  What were the best and worst things about publ...
# 2345795  2345795  What is the best medication equation erectile ...
#
#                                                  question2
# 0        Why did Microsoft choose core m3 and not core ...
# ...

# %%
res = pandas.read_pickle('./PandasStore/challenge_newsgroup_proba.pkl')
res
# Out:
#          proba_religion_question1  proba_computers_question1  \
# 0                        0.110380                   0.652538
# 1                        0.014415                   0.087211
# 2                        0.213368                   0.110256
# 3                        0.124571                   0.028182
# 4                        0.092368                   0.149464
# ...                           ...                        ...
# 2345791                  0.087479                   0.014999
# 2345792                  0.306997                   0.088314
# 2345793                  0.087004                   0.013482
# 2345794                  0.328955                   0.090073
# 2345795                  0.014543                   0.074075
#
#          proba_forsale_question1  proba_vehicles_question1  \
# 0                       0.000474                  0.005932
# 1                       0.002142                  0.183346
# ...

# %%
res = pandas.read_pickle('./PandasStore/challenge_questions_question_1_50.pkl')
res
